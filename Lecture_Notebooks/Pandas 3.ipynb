# %%
import numpy as np
import pandas as pd

# %% [markdown]
# A large monad is sitting on the top of a staircase. It has just two
# possible operations: 'descend one stair lower' and 'descend two stairs
# lower'.
# Question: how many unique ways of descending to the ground does the
# monad have?

# %% [markdown]
# ## Grouping and aggregate functions

# %%
species_df = pd.read_csv('species.csv')
surveys_df = pd.read_csv('surveys.csv')

# %%
species_df.head(3)
# Out:
#   species_id             genus     species    taxa
# 0         AB        Amphispiza   bilineata    Bird
# 1         AH  Ammospermophilus     harrisi  Rodent
# 2         AS        Ammodramus  savannarum    Bird

# %%
surveys_df.head(3)
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN

# %%
surveys_by_sex_df = surveys_df.groupby('sex')
surveys_by_sex_df

# %%
surveys_by_sex_df['hindfoot_length'].describe()
# Out:
#        count       mean       std  min   25%   50%   75%   max
# sex
# F    14894.0  28.836780  9.463789  7.0  21.0  27.0  36.0  64.0
# M    16476.0  29.709578  9.629246  2.0  21.0  34.0  36.0  58.0

# %%
print(surveys_by_sex_df['hindfoot_length'].min())
print("-----------------------------")
print(surveys_by_sex_df['hindfoot_length'].quantile(0.90))
# Out:
# sex
# F    7.0
# M    2.0
# Name: hindfoot_length, dtype: float64
# -----------------------------
# sex
# F    37.0
# M    38.0
# Name: hindfoot_length, dtype: float64

# %%
# Applying custom functions to each group

def my_fun(series):
    return np.std(series)
    
aggregated_data = surveys_by_sex_df.agg({'weight': my_fun,
                                         'hindfoot_length': np.mean})
aggregated_data
# Out:
#         weight  hindfoot_length
# sex
# F    36.846754        28.836780
# M    36.183909        29.709578

# %%
merged_df = pd.merge(species_df, surveys_df, on='species_id')
merged_df.sample(5)
# Out:
#       species_id        genus       species    taxa  record_id  month  day  \
# 29373         PP  Chaetodipus  penicillatus  Rodent      22820      9   24
# 16892         DS    Dipodomys   spectabilis  Rodent      16255      7    3
# 13472         DO    Dipodomys         ordii  Rodent      23385      2   24
# 5302          DM    Dipodomys      merriami  Rodent      11959     10    5
# 30059         PP  Chaetodipus  penicillatus  Rodent      26745      7   30
#
#        year  plot_id sex  hindfoot_length  weight
# 29373  1995        8   M             22.0    19.0
# 16892  1989       22   F              NaN   119.0
# 13472  1996        1   F             34.0    59.0
# 5302   1986       11   F             34.0    43.0
# 30059  1997        9   F             21.0    15.0

# %%
# Grouping by multiple columns
grouped_by_species_sex_df = merged_df.groupby(['species', 'sex'])
grouped_by_species_sex_df[['hindfoot_length', 'weight']].describe()
# Out:
#                  hindfoot_length                                         \
#                            count       mean       std   min   25%   50%
# species      sex
# albigula     F             620.0  32.024194  1.669181  21.0  31.0  32.0
#              M             452.0  32.577434  1.903603  21.0  32.0  33.0
# baileyi      F            1645.0  25.882675  0.928842  20.0  25.0  26.0
#              M            1213.0  26.431987  1.444130   2.0  26.0  26.0
# eremicus     F             544.0  20.272059  1.156084  15.0  20.0  20.0
#              M             666.0  20.132132  1.177721  11.0  20.0  20.0
# flavus       F             721.0  15.550624  1.381627   7.0  15.0  16.0
#              M     20.0   21.00   23.0
# maniculatus  F     22.0   25.00   35.0
#              M     21.0   24.00   49.0
# megalotis    F     11.0   13.00   21.0
#              M     10.0   11.00   29.0
# merriami     F     42.0   46.00   66.0
#              M     45.0   49.00   62.0
# montanus     F     11.5   12.25   13.0
#              M      9.5   10.25   11.0
# ochrognathus F     48.0   77.50  105.0
#              M     51.5   65.50   86.0
# ordii        F     49.0   54.00   76.0
#              M     51.0   54.00   67.0
# penicillatus F     17.0   19.00   74.0
#              M     17.0   20.00   42.0
# sp.          F     20.0   21.00   22.0
#              M     20.0   21.00   24.0
# spectabilis  F    120.0  130.00  190.0
#              M    128.0  138.00  170.0
# spilosoma    F     57.0   57.00   57.0
#              M    130.0  130.00  130.0
# taylori      F      9.0   10.00   18.0
#              M      7.0    8.00    9.0
# torridus     F     25.0   27.00   46.0
#              M     24.0   26.00   36.0

# %%
# We can also apply() a function to the whole group. This isn't as useful as agg()
# as normally we'd prefer to apply functions to specific columns.

def get_stats(group):
    return {'min': group.min(), 'max': group.max()}

grouped_by_species_sex_df[['hindfoot_length', 'year']].apply(get_stats)
# Out:
# species       sex
# albigula      F      {'min': [21.0, 1977.0], 'max': [38.0, 2002.0]}
#               M      {'min': [21.0, 1977.0], 'max': [42.0, 2002.0]}
# baileyi       F      {'min': [20.0, 1995.0], 'max': [36.0, 2002.0]}
#               M       {'min': [2.0, 1996.0], 'max': [47.0, 2002.0]}
# eremicus      F      {'min': [15.0, 1977.0], 'max': [30.0, 2002.0]}
#               M      {'min': [11.0, 1977.0], 'max': [26.0, 2002.0]}
# flavus        F       {'min': [7.0, 1977.0], 'max': [38.0, 2002.0]}
#               M       {'min': [9.0, 1977.0], 'max': [22.0, 2002.0]}
# fulvescens    F      {'min': [15.0, 1988.0], 'max': [20.0, 1997.0]}
#               M      {'min': [16.0, 1982.0], 'max': [19.0, 1990.0]}
# fulviventer   F      {'min': [24.0, 1989.0], 'max': [36.0, 2002.0]}
#               M      {'min': [21.0, 1989.0], 'max': [38.0, 2002.0]}
# harrisi       M        {'min': [nan, 1995.0], 'max': [nan, 1995.0]}
# hispidus      F      {'min': [20.0, 1982.0], 'max': [33.0, 2002.0]}
#               M      {'min': [21.0, 1977.0], 'max': [39.0, 2002.0]}
# intermedius   M      {'min': [22.0, 1995.0], 'max': [23.0, 2002.0]}
# leucogaster   F      {'min': [15.0, 1977.0], 'max': [24.0, 1997.0]}
#               M      {'min': [12.0, 1978.0], 'max': [39.0, 2002.0]}
# leucopus      F      {'min': [10.0, 1995.0], 'max': [22.0, 1998.0]}
#               M      {'min': [18.0, 1995.0], 'max': [22.0, 2000.0]}
# maniculatus   F      {'min': [17.0, 1978.0], 'max': [32.0, 2001.0]}
#               M      {'min': [16.0, 1978.0], 'max': [36.0, 2002.0]}
# megalotis     F       {'min': [9.0, 1977.0], 'max': [22.0, 2002.0]}
#               M       {'min': [6.0, 1977.0], 'max': [22.0, 2002.0]}
# merriami      F      {'min': [16.0, 1977.0], 'max': [50.0, 2002.0]}
#               M      {'min': [21.0, 1977.0], 'max': [48.0, 2002.0]}
# montanus      F      {'min': [14.0, 1991.0], 'max': [16.0, 2002.0]}
#               M      {'min': [15.0, 2002.0], 'max': [17.0, 2002.0]}
# ochrognathus  F      {'min': [15.0, 1991.0], 'max': [36.0, 1997.0]}
#               M      {'min': [21.0, 1991.0], 'max': [28.0, 1994.0]}
# ordii         F      {'min': [26.0, 1977.0], 'max': [64.0, 2002.0]}
#               M      {'min': [27.0, 1977.0], 'max': [58.0, 2002.0]}
# penicillatus  F      {'min': [11.0, 1977.0], 'max': [41.0, 2002.0]}
#               M      {'min': [13.0, 1977.0], 'max': [27.0, 2002.0]}
# sp.           F      {'min': [19.0, 1977.0], 'max': [21.0, 1997.0]}
#               M      {'min': [13.0, 1977.0], 'max': [21.0, 1997.0]}
# spectabilis   F      {'min': [39.0, 1977.0], 'max': [58.0, 1999.0]}
#               M      {'min': [40.0, 1977.0], 'max': [57.0, 1999.0]}
# spilosoma     F        {'min': [nan, 1981.0], 'max': [nan, 1981.0]}
#               M        {'min': [nan, 1978.0], 'max': [nan, 1992.0]}
# taylori       F       {'min': [7.0, 1990.0], 'max': [16.0, 1992.0]}
#               M       {'min': [6.0, 1989.0], 'max': [14.0, 1992.0]}
# torridus      F      {'min': [13.0, 1977.0], 'max': [50.0, 2002.0]}
#               M      {'min': [13.0, 1977.0], 'max': [29.0, 2002.0]}
# dtype: object

# %% [markdown]
# ## Useful operations

# %%
merged_df.sample(4)
# Out:
#       species_id            genus    species    taxa  record_id  month  day  \
# 18            AB       Amphispiza  bilineata    Bird       5256      1   24
# 27226         PF      Perognathus     flavus  Rodent      25842      5   11
# 26755         PF      Perognathus     flavus  Rodent      22982     10   29
# 32285         RM  Reithrodontomys  megalotis  Rodent      13663     11   21
#
#        year  plot_id  sex  hindfoot_length  weight
# 18     1982       12  NaN              NaN     NaN
# 27226  1997        4    M             15.0    10.0
# 26755  1995        9    F             16.0     8.0
# 32285  1987       21    M             18.0    14.0

# %%
# Binning a numerical variable into categories
weight_bins = [0, 30, 200, 300]
group_names = ['light', 'medium', 'heavy']
merged_df['weight_bins'] = pd.cut(merged_df['weight'],
                                  weight_bins,
                                  labels=group_names)

merged_df.sample(4)
# Out:
#       species_id        genus       species    taxa  record_id  month  day  \
# 5738          DM    Dipodomys      merriami  Rodent      13366      9   26
# 5867          DM    Dipodomys      merriami  Rodent      13872      1   23
# 10233         DM    Dipodomys      merriami  Rodent      28936     12   22
# 30237         PP  Chaetodipus  penicillatus  Rodent      28484      9   19
#
#        year  plot_id sex  hindfoot_length  weight weight_bins
# 5738   1987       24   F             37.0    40.0      medium
# 5867   1988       22   M             37.0    46.0      medium
# 10233  1998       12   M             37.0    39.0      medium
# 30237  1998       12   M             22.0    13.0       light

# %%
# We can use qcut() to create bins automatically based on quantiles
# E.g. q=4 would give us quartiles

merged_df['year_bins'] = pd.qcut(merged_df['year'],
                                 q=5,
                                 labels=["early","earlyish","medium","late","lateish"])

merged_df.sample(4)
# Out:
#       species_id      genus      species    taxa  record_id  month  day  year  \
# 15633         DS  Dipodomys  spectabilis  Rodent       4345      4    6  1981
# 10477         DM  Dipodomys     merriami  Rodent      29510      4   18  1999
# 7455          DM  Dipodomys     merriami  Rodent      19704      2    7  1992
# 19409         OT  Onychomys     torridus  Rodent       2031      9   22  1979
#
#        plot_id sex  hindfoot_length  weight weight_bins year_bins
# 15633       13   M              NaN   137.0      medium     early
# 10477        4   M             35.0    30.0       light   lateish
# 7455         4   F             38.0    38.0      medium    medium
# 19409       11   M             19.0    27.0       light     early

# %%
# Counting missing values in a column
print(merged_df['sex'].isnull().sum())
print(merged_df['sex'].notnull().sum())
# Out:
# 1748
# 33038

# %%
# Finding columns containing missing values
print(merged_df.isnull().any())
# Out:
# species_id         False
# genus              False
# species            False
# taxa               False
# record_id          False
# month              False
# day                False
# year               False
# plot_id            False
# sex                 True
# hindfoot_length     True
# weight              True
# weight_bins         True
# year_bins          False
# dtype: bool

# %%
# Show a sample of rows with missing weights
merged_df[merged_df['weight'].isnull()].sample(4)
# Out:
#       species_id             genus      species    taxa  record_id  month  \
# 13903         DO         Dipodomys        ordii  Rodent      27633      3
# 34637         SS      Spermophilus    spilosoma  Rodent      15817      3
# 497           AH  Ammospermophilus      harrisi  Rodent      20461     10
# 14526         DS         Dipodomys  spectabilis  Rodent        211      9
#
#        day  year  plot_id  sex  hindfoot_length  weight weight_bins year_bins
# 13903    2  1998        8    F             36.0     NaN         NaN      late
# 34637   14  1989        9  NaN              NaN     NaN         NaN    medium
# 497     18  1992       23  NaN              NaN     NaN         NaN    medium
# 14526   12  1977        4    F             48.0     NaN         NaN     early

# %%
# Drop rows with missing weight values
# As always, set inplace=True to perform operation in place
new_df = merged_df.dropna(subset=['weight'])
print(merged_df['weight'].isnull().sum())
print(new_df['weight'].isnull().sum())
# Out:
# 2503
# 0

# %%
# Substitute the value 0 for missing weights
new_df = merged_df.copy()
new_df['weight'] = merged_df['weight'].fillna(value=0)
new_df[new_df.weight == 0].head(3)
# Out:
#   species_id       genus    species  taxa  record_id  month  day  year  \
# 0         AB  Amphispiza  bilineata  Bird       3126      7   21  1980
# 1         AB  Amphispiza  bilineata  Bird       3146      7   21  1980
# 2         AB  Amphispiza  bilineata  Bird       3152      7   21  1980
#
#    plot_id  sex  hindfoot_length  weight weight_bins year_bins
# 0        8  NaN              NaN     0.0         NaN     early
# 1       24  NaN              NaN     0.0         NaN     early
# 2       19  NaN              NaN     0.0         NaN     early

# %% [markdown]
# See [here](https://pandas.pydata.org/pandas-docs/stable/missing_data.html) for more details on how calculations work with missing data. For example, descriptive statistics will treat a NaN as zero whenever they need to compute a sum.

# %%
merged_df.sample(4)
# Out:
#      species_id      genus   species    taxa  record_id  month  day  year  \
# 8993         DM  Dipodomys  merriami  Rodent      24275      7   21  1996
# 980          DM  Dipodomys  merriami  Rodent        162      9   11  1977
# 2374         DM  Dipodomys  merriami  Rodent       4081      4    5  1981
# 3574         DM  Dipodomys  merriami  Rodent       7633      3   15  1983
#
#       plot_id sex  hindfoot_length  weight weight_bins year_bins
# 8993        4   M             38.0    45.0      medium      late
# 980         6   F             39.0    45.0      medium     early
# 2374        1   M              NaN    50.0      medium     early
# 3574        1   M             38.0    52.0      medium     early

# %%
# Convert the categorical sex variable into a dummy variable
merged_df.dropna(subset=['sex'], inplace=True)
dummy_df = pd.get_dummies(merged_df['sex'])
merged_df = pd.concat([merged_df, dummy_df], axis=1)
merged_df.head(3)
# Out:
#     species_id             genus  species    taxa  record_id  month  day  \
# 542         AH  Ammospermophilus  harrisi  Rodent      22330      6    8
# 742         BA           Baiomys  taylori  Rodent      16598     11    4
# 743         BA           Baiomys  taylori  Rodent      16599     11    4
#
#      year  plot_id sex  hindfoot_length  weight weight_bins year_bins  F  M
# 542  1995       16   M              NaN     NaN         NaN      late  0  1
# 742  1989       21   M             13.0     7.0       light    medium  0  1
# 743  1989       21   M             12.0     6.0       light    medium  0  1

# %%
# Applying a function to several columns, creating a new column as an output
def animal_bmi(row):
    if row['sex'] == 'M':
        return row['weight'] / row['hindfoot_length'] ** 2
    else:
        return row['weight'] / row['hindfoot_length'] ** 3
    
merged_df['bmi'] = merged_df.apply(animal_bmi, axis=1)
merged_df.head(3)
# Out:
#     species_id             genus  species    taxa  record_id  month  day  \
# 542         AH  Ammospermophilus  harrisi  Rodent      22330      6    8
# 742         BA           Baiomys  taylori  Rodent      16598     11    4
# 743         BA           Baiomys  taylori  Rodent      16599     11    4
#
#      year  plot_id sex  hindfoot_length  weight weight_bins year_bins  F  M  \
# 542  1995       16   M              NaN     NaN         NaN      late  0  1
# 742  1989       21   M             13.0     7.0       light    medium  0  1
# 743  1989       21   M             12.0     6.0       light    medium  0  1
#
#           bmi
# 542       NaN
# 742  0.041420
# 743  0.041667

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'],
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}
army_df = pd.DataFrame(raw_data, columns = ['regiment', 'company', 'name', 'preTestScore', 'postTestScore'])
army_df
# Out:
#       regiment company      name  preTestScore  postTestScore
# 0   Nighthawks     1st    Miller             4             25
# 1   Nighthawks     1st  Jacobson            24             94
# 2   Nighthawks     2nd       Ali            31             57
# 3   Nighthawks     2nd    Milner             2             62
# 4     Dragoons     1st     Cooze             3             70
# 5     Dragoons     1st     Jacon             4             25
# 6     Dragoons     2nd    Ryaner            24             94
# 7     Dragoons     2nd      Sone            31             57
# 8       Scouts     1st     Sloan             2             62
# 9       Scouts     1st     Piger             3             70
# 10      Scouts     2nd     Riani             2             62
# 11      Scouts     2nd       Ali             3             70

# %% [markdown]
# ## Exercises
#
# 1. Group the army data by company. Print descriptive statistics for `preTestScore` and `postTestScore` for each company.
#
# 2. Group the army data by regiment and company. Print the mean `preTestScore` and maximum `postTestScore` for each group in a single table.
#
# 3. Bin `postTestScore` into 3 bins. Put these bins into a new column.
#
# 4. Convert the categorical `company` variable into a dummy variable. Put this into a new column.
#
# 5. Create a new column that contains `preTestScore` * `postTestScore` for people in the 1st company, and `preTestScore` + `postTestScore` for people in the 2nd company.
